# %% [markdown]
# Installing libraries we are going to use

# %%
# pip install sklearn
# pip install pandas
# pip install numpy
# pip install tensorflow
# pip install keras

# NOTE: Installing Keras and Tensorflow may vary if you are using anaconda,
# consider googling which best suites your case.Run the following commands in gitbash

# %%
#import libraries
import pandas as pd
import numpy as np
from sklearn.utils import shuffle

# %% [markdown]
# Load Dataset

# %%
# load dataset
df=pd.read_csv('static/RamanScatter.csv')

# %%
# print the first 5 rows
print(df.head(5))
# Out:
#   Incident Frequencies Modified anti-Stokes frequencies    Unnamed: 2  \
# 0         ω1 * 1014s-1                     ω1 + ω2 + ωD  ω1 + ω2 - ωD
# 1                46.52                            46.52         57.58
# 2                38.61                            38.61         49.67
# 3                35.38                            35.38         46.44
# 4                29.63                            29.63         40.69
#
#   Modified Stokes frequencies    Unnamed: 4
# 0                ω1 - ω2 - ωD  ω1 - ω2 + ωD
# 1                       49.34         35.46
# 2                       41.43         27.55
# 3                        38.2         24.32
# 4                       32.45         18.57

# %%
# remove the header
df.columns = [''] * len(df.columns)

# %%
#  assign column names
df.columns = ['Frequency_0','Frequency_1','Frequency_2','Frequency_3','Frequency_4']

# %%
# delete the first row 
df=df.drop(df.index[0])

# %%
# shuffle our data randomly then reset the index
df=shuffle(df,random_state=1)
df=df.reset_index(drop=True)

# %%
df.head(5)
# Out:
#   Frequency_0 Frequency_1 Frequency_2 Frequency_3 Frequency_4
# 0       17.71       22.43       21.63       12.99       13.79
# 1       29.63       40.96       32.09        18.3       27.17
# 2       17.71       29.04       20.17        6.38       15.25
# 3        22.7       27.04       26.75       18.36       18.65
# 4       18.29       24.03       23.76       12.55       12.82

# %%
df.shape
# Out:
# (80, 5)

# %% [markdown]
# Since we have only 80 rows in our dataset, we will need to do data augmentation to prevent the likelyhood of overfitting during training of the model.
#
# Overfitting occurs when the model performs well on the training data but does not perform accurately in the testing data.
# Data Augmentation is the techniques used to increase the amount of data by adding slightly modified copies of already existing data.

# %%
#perform data augmentation to remove likelyhood of overfitting
unique=df['Frequency_0'].unique().tolist()
Frequency_0=unique * 1000
import random 
random_list=[]
for i in range(0,8000):
    x=round(random.uniform(1.10,10.10),2)
    random_list.append(x)
# print(random_list)

# %%
list_1=[]
for i in range(0,8000):
    x=round(random.uniform(7.00,9.90),2)
    list_1.append(x)
# print(list_1)

# %%
df_from_list_0 = pd.DataFrame (Frequency_0, columns = ['Frequency_0'])
df_from_list= pd.DataFrame (random_list, columns = ['Difference'])

result = pd.concat([df_from_list_0, df_from_list], axis=1, join='inner')
# print (result.head(5))
# Out:
#   Frequency_0  Difference
# 0       17.71        4.32
# 1       29.63        8.44
# 2        22.7        9.75
# 3       18.29        9.74
# 4       35.38        5.28

# %%
result['Frequency_1']=result['Frequency_0'].astype(float) + result['Difference']
result['Frequency_2']=result['Frequency_1'].astype(float) - result['Difference'] - 1.00
df_from_list_1= pd.DataFrame (list_1, columns = ['Difference_1'])
result = pd.concat([result, df_from_list_1], axis=1, join='inner')
# result.head(5)
# Out:
#   Frequency_0  Difference  Frequency_1  Frequency_2  Difference_1
# 0       17.71        4.32        22.03        16.71          7.79
# 1       29.63        8.44        38.07        28.63          7.95
# 2        22.7        9.75        32.45        21.70          9.79
# 3       18.29        9.74        28.03        17.29          7.29
# 4       35.38        5.28        40.66        34.38          9.74

# %%
result['Frequency_3']=result['Frequency_0'].astype(float) - result['Difference_1']
result['Frequency_4']=result['Frequency_3'] + result['Difference']
result['Frequency_0']=result['Frequency_0'].astype(float) * 1.0
result=result.drop(['Difference','Difference_1'], axis=1)
df=df.astype(float).multiply(1.0)
df_result = pd.concat([df, result], ignore_index=True, sort=False)
result.head(5)

# %%
df_result.shape
# Out:
# (8080, 5)

# %% [markdown]
# As you can see we have increased the size of the data from 80 rows to 8080 rows

# %% [markdown]
# Data Visualization

# %%
# visualize the data
import matplotlib.pyplot as plt
df.plot.line(figsize=(10,5))
# Out:
# <AxesSubplot:>

# %%
df.plot.area(figsize=(10,5))
# Out:
# <AxesSubplot:>

# %%
We are then creating a new column and name it frequency loss.Any atom that lost more than 4 frequencies of energy is said to have cance

# %%
df_result['Frequency_loss']=df_result['Frequency_1']-df_result['Frequency_2']
df_result['cancer_probability']= df_result['Frequency_loss'].apply(lambda x: 0 if x <= 4 else 1)
print(df_result.tail(20))

# %%
# Out:
#     Frequency_0  Frequency_1  Frequency_2  Frequency_3  Frequency_4  \
# 0         17.71        22.43        21.63        12.99        13.79
# 1         29.63        40.96        32.09        18.30        27.17
# 2         17.71        29.04        20.17         6.38        15.25
# 3         22.70        27.04        26.75        18.36        18.65
# 4         18.29        24.03        23.76        12.55        12.82
# 5         17.71        23.45        23.18        11.97        12.24
# 6         22.70        24.90        24.66        20.50        20.74
# 7         35.38        36.52        36.38        34.24        34.38
# 8         17.71        27.39        21.53         8.49        13.89
# 9         38.61        39.75        39.61        37.47        37.61
# 10        35.38        45.06        39.20        25.70        31.56
# 11        18.29        23.01        22.21        13.57        14.37
# 12        24.00        33.68        27.82        14.32        20.18
# 13        46.52        52.26        52.00        40.78        41.05
# 14        35.38        40.10        39.30        30.66        31.46
# 15        35.38        42.11        38.58        28.65        32.18
# 16        18.29        27.97        22.11         8.61        14.47
# 17        35.38        35.38        46.44        38.20        24.32
# 18        29.63        39.31        33.45        19.95        25.81
# 19        38.61        48.29        42.43        28.93        34.79
#
#     Frequency_loss  cancer_probability
# 0             0.80                   0
# 1             8.87                   1
# 2             8.87                   1
# 3             0.29                   0
# 4             0.27                   0
# 5             0.27                   0
# 6             0.24                   0
# 7             0.14                   0
# 8             5.86                   1
# 9             0.14                   0
# 10            5.86                   1
# 11            0.80                   0
# 12            5.86                   1
# 13            0.26                   0
# 14            0.80                   0
# 15            3.53                   0
# 16            5.86                   1
# 17          -11.06                   0
# 18            5.86                   1
# 19            5.86                   1

# %%
# plotting two columns
df.plot.line(y=['Frequency_1', 'Frequency_2'], figsize=(10,6))
# Out:
# <AxesSubplot:>

# %%
Features=df.filter(['Frequency_0','Frequency_1','Frequency_2'], axis=1)

# plotting Frequency_1
ax = df_result.head(20).plot(x="Frequency_0", y="Frequency_1", kind="bar",figsize=(10,5))
# plotting Frequency_2 on the same axis
df_result.head(20).plot(x="Frequency_0", y="Frequency_2", kind="bar", ax=ax, color="orange",figsize=(10,5))
# Out:
# <AxesSubplot:xlabel='Frequency_0'>

# %%
# plotting Frequency_1
ax = df_result.tail(20).plot(x="Frequency_0", y="Frequency_1", kind="bar",figsize=(10,5))
# plotting Frequency_2 on the same axis
df_result.tail(20).plot(x="Frequency_0", y="Frequency_2", kind="bar", ax=ax, color="pink",figsize=(10,5))
# Out:
# <AxesSubplot:xlabel='Frequency_0'>

# %%
# plotting Frequency_1
ax = df_result[500:520].plot(x="Frequency_0", y="Frequency_1", kind="bar",figsize=(10,5))
# plotting Frequency_2 on the same axis
df_result[500:520].plot(x="Frequency_0", y="Frequency_2", kind="bar", ax=ax, color="black",figsize=(10,5))
# Out:
# <AxesSubplot:xlabel='Frequency_0'>

# %%
# Neural Network

# %%
import tensorflow as tf
from keras.models import Sequential
import pandas as pd
from keras.layers import Dense
data = df_result
data=data.drop(['Frequency_loss'], axis=1)

# %%
data.head(5)
# Out:
#    Frequency_0  Frequency_1  Frequency_2  Frequency_3  Frequency_4  \
# 0        17.71        22.43        21.63        12.99        13.79
# 1        29.63        40.96        32.09        18.30        27.17
# 2        17.71        29.04        20.17         6.38        15.25
# 3        22.70        27.04        26.75        18.36        18.65
# 4        18.29        24.03        23.76        12.55        12.82
#
#    cancer_probability
# 0                   0
# 1                   1
# 2                   1
# 3                   0
# 4                   0

# %%
data.describe()
# Out:
#        Frequency_0  Frequency_1  Frequency_2  Frequency_3  Frequency_4  \
# count  8080.000000  8080.000000  8080.000000  8080.000000  8080.000000
# mean     29.105000    34.728244    28.154479    20.700446    26.282305
# std       9.664796     9.979208     9.680910     9.714222    10.010848
# min      17.710000    17.710000    16.710000     6.380000     6.650000
# 25%      21.597500    26.400000    21.700000    12.810000    17.980000
# 50%      26.815000    32.475000    28.630000    19.765000    24.180000
# 75%      36.187500    42.660000    37.610000    28.730000    34.182500
# max      46.520000    57.850000    57.580000    49.340000    49.420000
#
#        cancer_probability
# count         8080.000000
# mean             0.782178
# std              0.412791
# min              0.000000
# 25%              1.000000
# 50%              1.000000
# 75%              1.000000
# max              1.000000

# %%
import seaborn as sns
import matplotlib as plt
corr = data.corr()
sns.heatmap(corr, 
xticklabels=corr.columns.values,
yticklabels=corr.columns.values)
# Out:
# <AxesSubplot:>

# %%
print(data['Frequency_0'].corr( data["Frequency_2"]))
# 0.2818052888499106
print(data["Frequency_3"].corr(data["Frequency_4"]))
# 0.5443412284023394
# Out:
# 0.9983269439980406
# 0.9633097433070964

# %%
import numpy as np
labels=data['cancer_probability']
features = data.iloc[:,0:5]
from sklearn.model_selection import train_test_split
X=features
y=np.ravel(labels)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8080 entries, 0 to 8079
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Frequency_0         8080 non-null   float64
#  1   Frequency_1         8080 non-null   float64
#  2   Frequency_2         8080 non-null   float64
#  3   Frequency_3         8080 non-null   float64
#  4   Frequency_4         8080 non-null   float64
#  5   cancer_probability  8080 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 378.9 KB

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler().fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
def f(x):
    if x<=0:
        return 0
    elif x>0:
        return 1

# %%
from keras.models import Sequential
from keras.layers import Dense
model = Sequential()
model.add(Dense(5, activation='relu', input_shape=(5,)))
model.add(Dense(5, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy',
optimizer='sgd',
metrics=['accuracy'])
model.fit(X_train, y_train,epochs=4, batch_size=1, verbose=1)
# Out:
# Epoch 1/4
# 5413/5413 [==============================] - 7s 1ms/step - loss: 0.3602 - accuracy: 0.8398
# Epoch 2/4
# 5413/5413 [==============================] - 7s 1ms/step - loss: 0.1117 - accuracy: 0.9577
# Epoch 3/4
# 5413/5413 [==============================] - 7s 1ms/step - loss: 0.0917 - accuracy: 0.9619
# Epoch 4/4
# 5413/5413 [==============================] - 7s 1ms/step - loss: 0.0813 - accuracy: 0.9667

# %%
# printing model summary
for layer in model.layers:
    weights = layer.get_weights()
    print(weights)
# Out:
# [array([[-0.40013242,  0.7489149 ,  0.00916821, -1.1292498 , -0.18278952],
#        [ 0.3117766 , -1.0564896 ,  0.45797798,  2.9959269 ,  0.93588716],
#        [-0.40909103,  0.27099523, -0.42354897, -1.4819067 , -1.3279616 ],
#        [-0.74819624, -0.10449078, -0.39334977, -2.5639224 , -0.4030101 ],
#        [ 0.97328246, -0.00427032,  0.42281714,  2.483123  ,  1.0892977 ]],
#       dtype=float32), array([0.18473159, 0.22324361, 0.57338727, 1.8301216 , 0.71454906],
#       dtype=float32)]
# [array([[ 4.32242453e-01, -1.50575535e-03,  8.19153488e-01,
#          3.80289555e-03,  6.86074555e-01],
#        [ 2.11798266e-01,  1.06303346e+00, -1.60486057e-01,
#         -3.12366813e-01,  1.56466126e-01],
#        [ 1.05660164e+00,  6.31428719e-01,  1.30131736e-01,
#         -1.09259725e-01, -2.24666819e-01],
#        [ 1.99795282e+00, -1.23790753e+00,  1.16394424e+00,
#         -1.16332173e-01,  6.96834862e-01],
#        [ 6.51259780e-01, -6.41045094e-01,  4.08063173e-01,
#         -1.63257122e-02, -6.15811467e-01]], dtype=float32), array([-0.40539062,  1.3741933 ,  0.00234282,  0.        , -0.01486571],
#       dtype=float32)]
# [array([[ 2.1584902 ],
#        [-1.9788835 ],
#        [ 1.1429218 ],
#        [ 0.4736519 ],
#        [ 0.46362513]], dtype=float32), array([-0.3041818], dtype=float32)]

# %%
#  picture of the layers and their shapes. 
from keras.utils import plot_model
plot_model(model, to_file='/tmp/model.png', show_shapes=True,)

# %%
# configuration information on each layer
predictions = (model.predict(X_test) > 0.5).astype("int32")
score = model.evaluate(X_test, y_test,verbose=1)
print(score)
# print(predictions)
# Out:
# 84/84 [==============================] - 1s 2ms/step
# 84/84 [==============================] - 0s 1ms/step - loss: 0.0548 - accuracy: 0.9745
# [0.05480106174945831, 0.9745031595230103]

# %%
# summarize the first 5 cases
for i in range(20):
	print('%s => %d (expected %d)' % (X_train[i].tolist(), predictions[i], y_train[i]))
# Out:
# [-1.1276229744491861, -1.0508565627206863, -1.1313702229702, -1.1511627706888405, -1.0711774789329163] => 1 (expected 1)
# [-1.1876817713384364, -1.313856543024749, -1.1913792559603638, -1.0976234745939184, -1.2234727653599236] => 0 (expected 1)
# [-1.1276229744491861, -1.1248565571788636, -1.1313702229702, -1.1542515762327783, -1.1478228191608872] => 1 (expected 1)
# [-1.1876817713384364, -1.3988565366591423, -1.1913792559603638, -1.0924754653540218, -1.3031042876746988] => 1 (expected 1)
# [-0.5363544740394955, -0.9518565701347459, -0.5405916395670349, -0.6229770226754762, -1.0303663237465936] => 1 (expected 0)
# [0.04663005438547067, 0.1441433477863698, 0.041909835837486704, -0.0031567101919576946, 0.09940589909428053] => 1 (expected 1)
# [0.04663005438547067, 0.4291433264428644, 0.04190983583748707, 0.10289228014990695, 0.4856187823209406] => 1 (expected 1)
# [0.6420405407875237, 0.7431433029275637, 0.6368269732399738, 0.6609364817546703, 0.7653245044515897] => 1 (expected 1)
# [1.7955836396603702, 1.6391432358265778, 1.7894142620510525, 1.6678870890783934, 1.5218239664419544] => 1 (expected 1)
# [-0.5363544740394955, -0.7468565854870919, -0.5405916395670349, -0.46338873623869004, -0.6720244733301051] => 0 (expected 1)
# [0.04663005438547067, -0.004856641055095914, 0.041909835837486704, -0.04331118226314881, -0.08772817834544129] => 0 (expected 1)
# [1.7955836396603702, 1.4131432527516037, 1.7894142620510525, 1.8274753755151805, 1.4511509903875919] => 1 (expected 0)
# [-1.1876817713384364, -0.8358565788219267, -1.1913792559603638, -1.138807548513089, -0.7874901806865289] => 0 (expected 1)
# [0.04663005438547067, 0.43914332569396963, 0.04190983583748707, 0.15025396515695333, 0.5413608479412835] => 1 (expected 1)
# [1.7955836396603702, 1.516143245037986, 1.7894142620510525, 1.7265743944132117, 1.456127960532265] => 1 (expected 1)
# [0.9765059096707633, 1.1551432720730923, 0.9710152086851964, 0.9965866841959109, 1.1784130264594856] => 1 (expected 1)
# [0.6420405407875237, 0.25614333939874706, 0.6368269732399738, 0.6393148429471057, 0.2596643377527661] => 1 (expected 0)
# [-0.5363544740394955, -0.8898565747778944, -0.5405916395670349, -0.5498752914689483, -0.8979789178982799] => 0 (expected 0)
# [-1.1876817713384364, -0.9958565668396079, -1.1913792559603638, -1.1480739651449026, -0.9557117715764918] => 1 (expected 1)
# [-0.5363544740394955, -0.9458565705840826, -0.5405916395670349, -0.40573103275185085, -0.8143658194677655] => 1 (expected 0)
